# %%
import pandas as pd
import numpy as np
import re
from collections import Counter

# %%
data = pd.read_csv("book-data.txt", error_bad_lines=False)
# Out:
# C:\Users\Aman\AppData\Local\Temp\ipykernel_10496\1799883999.py:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   data = pd.read_csv("book-data.txt", error_bad_lines=False)
# ...

# %%
data.rename(columns={"The Project Gutenberg EBook of Moby Dick; or The Whale":"words"}, inplace = True)

# %%
# compress = re.findall("w+", )

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer()

# %%
vectors = cv.fit_transform(data["words"])

# %%
v = set(cv.vocabulary_)

# %%
print(type(v))
# Out:
# <class 'set'>

# %%
len(cv.vocabulary_)
# Out:
# 13412

# %%
counter = cv.vocabulary_

# %%
# frequency = Counter(counter)
# frequency.most_common()[0:10]

# %%
from nltk.metrics.distance import jaro_similarity, jaccard_distance

# %%
jaro_similarity("aman", "amit")
# Out:
# 0.6666666666666666

# %%
def myauto_correct(word):
    l=[]
    if word in v:
        pass
    else:
        
        for w in v:
            distance = jaro_similarity(w, word)
            l.append(distance)
            similar = sorted(l, reverse=True)[0:5]
#             s = pd.DataFrame(similar).reset_index()
            
            
            
        return print(similar)

# %%
myauto_correct("the")

# %%
list(frequency.items())[0:10][0:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 list(frequency.items())[0:10][0:10]
#
# NameError: name 'frequency' is not defined

# %%
ten = sorted(list(frequency.values()), reverse=True)[10:20]
